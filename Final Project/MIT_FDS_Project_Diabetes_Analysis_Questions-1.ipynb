# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Indians tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ## Q 1: Import the necessary libraries and briefly explain the use of each library (3 Marks)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 1:
# - **Numpy**: is a library suited to work with homogeneous numerical data, such as arrays. It is a fundamental package for scientific computing useful in linear algebra, vector calculus etc.
# - **Pandas**: is a library used to work with heterogeneous and tabular data. It contains data structure and data manipulation tools designed for data cleaning and analysis, it is build on top of Numpy and it offers two major data structures: series and dataframes
# - **Matplotlib**: is a library used for data visualization. pyplot is a subpackage of matplotlib that provides a matlab-like way of plotting graphics, it is python 2D plotting library
# - **Seaborn**: is a python visualization library, it provides a high-level interface for plotting statistical graphics. the library uses matplotlib in the backend

# %% [markdown]
# ## Q 2: Read the given dataset (1 Mark)

# %%
pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ## Q3. Show the last 10 records of the dataset. How many columns are there? (1 Mark)

# %%
pima.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 3: there are 10 columns

# %% [markdown]
# ## Q4. Show the first 10 records of the dataset (1 Mark)

# %%
pima.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe. (1 Mark)

# %%
pima.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 5: I understand that there are 768 rows and 9 columns. the output of .shape is a tuple of 2 values

# %% [markdown]
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe. (1 Mark)

# %%
pima.size
# Out:
# 6912

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 6: I understand the number of elements in the dataset: 6912 in this case. 768x9=6912

# %% [markdown]
# ## Q7. What are the data types of all the variables in the data set? (2 Marks)
# **Hint: Use info() function to get all the information about the dataset.**

# %%
pima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 7:
#
# - There are 768 observations and 9 columns
# - all the columns have non-null values: there are no missing values in the data
# <br>
#
# The data type of the variables in the dataset are:
#
# - float64: DiabetesPedigreeFunction, BMI
# - int64: all the others

# %% [markdown]
# ## Q8. What do you mean by missing values? Are there any missing values in the `pima` dataframe? (2 Marks)

# %%
pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 8: Missing values are indicated in the dataframe as NaN, because no value is associated with that cell. Missing values occur when no data value is stored for the variable in an observation. They can heve a significant effect on the inferences that are drawn from the data.
# The output of the above code (False) implies that there are no missing values in the data

# %% [markdown]
# ## Q9. What does summary statistics of data represents? Find the summary statistics for all variables except 'Outcome' in the `pima` data? Take one column/variable from the output table and explain all the statistical measures. (3 Marks)

# %%
pima.iloc[:,0:8].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# ...

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 9: The summary statistics represents the 5 number summary that includes the descriptive statistics of minimum, first quartile (25%), median (quantile 50%), third quartile (75%) and maximum to give a picture of the data. The mean and the standard deviation (std) can also be used to convey the center and the spread of a set of data. However both of these statistics are susceptible to outliers.
#
# For example if we consider the colum 'Age':
# - the count is the sum of all values in the variable 'Age'
# - the mean is the average age present in the dataset and it is a key measure of central tendency
# - std: is a measure of variation/dispersion of data points with respect to the mean
# - min: is the minimum value found among all values in the variabile Age in the dataframe --> the youngest person is 21 years old
# - 25%: is the first quartile Q1 which indicates that 25% of our data falls below the first quartile
# - 50%: is the median, or second quartile, which is the midway point of the data. 50% of all data falls below the median. Like mean, it's another measure of central tendency. Median is a preferred metric over mean if there are outliers or high variability in the data
# - 75%: is the third quartile Q3, 75% of our data falls below the third quartile
# - max: is the max value found among all values in the variable Age in the dataframe--> the oldest person is 81 years old
#
# The summary statistics helps to describe the center, spread and shape of the distirbution
# - the mean is 33.240885 and the age ranges from 21 to 81, indicating a good range diversity
# - the mean 33.240885 > the median 29.000000 indicating that the associated distirbution is right skewed (confirmed by displot)
# - IQR= Q3-Q1= 41-24= 17 indicates how large is the spread around the central tendency
# - a large difference between the 75th percentile (41) and the maximum value (81) indicates the presence of potential outliers (confirmed by the boxplot in which we can visualize this situation)
# - the difference between the minimum value and the 25th percentile is not large, this implies that no outliers should be found in this region (confirmed by boxplot)

# %%
sns.displot(pima['Age'], kde= True)
plt.axvline(x=pima['Age'].mean(), linewidth=3, color='r')
plt.axvline(x=pima['Age'].median(), linewidth=3, color='b')

# %% [markdown]
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)

# %%
sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 10:
# Distribution is not symmetric due to the presence of outliers: most observations lie between 45 and 90 but there is also a second peak on the left in which most of the oberservations lie between -10 and 10, these are outliers since Blood Pressure cannot be negative. In statistics, an outlier is an observation point that is distant from other observations. These data are being likely due to measurment error and they are too extreme to be believable. It may be best to exlude them and analyze the data without them. We can set a threshold using IQR and remove the outliers greater than that threshold value.

# %% [markdown]
# ## Q 11. What is the 'BMI' for the person having the highest 'Glucose'? (1 Mark)

# %%
pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %%
pima[pima['Glucose']==pima['Glucose'].max()]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 11: The max glucose found is 199 and the BMI which corresponds to this value of glucose is 42.9. These values can be found at row 661

# %% [markdown]
# ## Q12.
# ### 12.1 What is the mean of the variable 'BMI'?
# ### 12.2 What is the median of the variable 'BMI'?
# ### 12.3 What is the mode of the variable 'BMI'?
# ### 12.4 Are the three measures of central tendency equal?
#
# ### (3 Marks)

# %%
m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median()  #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 31.992578124999977
# 32.0
# 32.0

# %%
sns.distplot(pima['BMI'], kde=True, hist=False)
plt.axvline(x=pima['BMI'].mean(), color='red')
plt.axvline(x=pima['BMI'].median(), color='darkgreen')
plt.axvline(x=pima['BMI'].mode()[0], color='magenta')

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 12: They are almost equal:  31.99, 32 and 32. it means that there is no Skew: Mean = Median = Mode and thus the distribution is symmetrical on both sides, or as in this case, almost symmetrical, due to the fact that we have some outliers around 0. They are probably measurment errors since it is impossibile to have negative BMI

# %% [markdown]
# ## Q13. How many women's 'Glucose' level is above the mean level of 'Glucose'? (1 Mark)

# %%
pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 349

# %%
pima['Glucose'].mean()
# Out:
# 120.89453125

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 13: The glucose mean is 120.89453125 and 349 women have the glucose value above the mean glucose value, indicating that these people probably have diabetes

# %% [markdown]
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'? (2 Marks)

# %%
pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())].shape[0]
# Out:
# 22

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 14: 22 women meet the conditions

# %% [markdown]
# ## Q15. Create the pairplot for variables 'Glucose', 'SkinThickness' and 'DiabetesPedigreeFunction'. Write you observations from the plot. (4 Marks)

# %%
sns.pairplot(data=pima,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 15: <br>
# The pairplot shows the relationship between a pair of variables. It comes handy when we want to go for Exploratory Data Analysis (EDA). On the diagonal axis a plot shows the univariate distirbution of each variable.
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
#
# We can see the correlation (statistic that measures the degree to which 2 variables move with each other) between 2 variables.
#
# From these plots it doesn't seem to be any evident strong correlation between the variables but clusters can be identified.
# For example in the glucose plots we can identify a cluster of helathy people and a cluster of women that have diabetes, these clusters remain almost separate, this makes sense since high levels of glucose are tipically found in diabetes thus healthy people will tend to have lower values for glucose. However, some outliers can be found.
#
# <br>
#
# Moderate correlation can be seen between Diabetes Pedigree Function (on y axis) and Skin Thickness (on x axis). Given that diabetic patients have thicker skin, this correlation suggests that the genetic factor influences the development of the pathology.

# %% [markdown]
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. (2 Marks)

# %%
sns.scatterplot(x='Glucose',y='Insulin',data=pima)
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 16: The scatterplot is a set of points used to study correlation between 2 variables and also the detection of extreme data points. We can say that the 2 variables are positively correlated, since with the increase of glucose there is also an increse of insulin. This makes sense considering a physiological condition.
# However, it must be observed the straight line for insulin=0 despite the increasing glucose. We might say that these points are describing the pathological condition in which insulin cannot be detected in the bloodstream thus it cannot remove the glucose, these points do not follow the general pattern.
# Moreover, there can also be observed several points on the top of the graph which are not entirely following the trend: it seems that for a given value of glucose these people produce more insulin with respect to the people in the cluster that are following the correlation line. In the plot we can also observe 2 points in x=0, they are probably outliers due to the measurment errors.

# %% [markdown]
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? (2 Marks)

# %%
plt.boxplot(pima['Age'])

# add labels for five number summary
plt.text(x = 1.1, y = pima['Age'].min(), s ='min')
plt.text(x = 1.1, y = pima.Age.quantile(0.25), s ='Q1')
plt.text(x = 1.1, y = pima['Age'].median(), s ='meadian (Q2)')
plt.text(x = 1.1, y = pima.Age.quantile(0.75), s ='Q3')
plt.text(x = 1.1, y = pima['Age'].max(), s ='max')

# add an arrow (annonate) to show the outliers
plt.annotate('Outliers', xy = (0.97,45),xytext=(0.7, 44), arrowprops = dict(facecolor='black', arrowstyle = 'simple'))

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 17: Yes, there are outliers on the top as we can see in the figure, they are marked with dots

# %% [markdown]
# ## Q18. Plot histograms for variable Age to understand the number of women in different Age groups given that they have diabetes or not. Explain both histograms and compare them. (3 Marks)

# %%
plt.figure(figsize=(15,4))

# FIRST PLOT
plt.subplot(1, 2, 1)
plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5, density=True, color='r', alpha=0.2)
#mean 
plt.axvline(x=pima[pima['Outcome']==1]['Age'].mean(), linewidth=2, color='r', label='Mean')
#median 
plt.axvline(x=pima[pima['Outcome']==1]['Age'].median(), linewidth=2, color='g', label='Median')
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()

# SECOND PLOT 
plt.subplot(1, 2, 2)
plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5, density=True, color='r', alpha=0.2)
#mean 
plt.axvline(x=pima[pima['Outcome']==0]['Age'].mean(), linewidth=2, color='r', label='Mean')
#median 
plt.axvline(x=pima[pima['Outcome']==0]['Age'].median(), linewidth=2, color='g', label='Median')
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5, density=True, color='plum', alpha=0.9, label= 'Diabetes (1)')
plt.axvline(x=pima[pima['Outcome']==1]['Age'].mean(), linewidth=2, color='r', label='Mean (1)')
plt.axvline(x=pima[pima['Outcome']==1]['Age'].median(), linewidth=2, color='g', label='Median (1)')


plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5, density=True, color='b', alpha=0.5, label= 'No Diabetes (2)')
plt.axvline(x=pima[pima['Outcome']==0]['Age'].mean(), linewidth=2, color='magenta', label='Mean (2)')
plt.axvline(x=pima[pima['Outcome']==0]['Age'].median(), linewidth=2, color='cyan', label='Median (2)')

plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 18: A histogram is an accurate representation of the distribution of numerical data. In order to compare the two plots and to have a better visualization we can plot them together on the same scale.
#
# - From the first histogram we can see that women with diabetes between 20 and 30 years old are more frequent than the others, in particular there is a **decreasing trend of women having diabetes with the increase of the age**. We can state almost the same thing about the second histogram (No Diabetes) in which the frequency associated with the first bin (21-33 y.o.) is higher with respect to the others, we can actually see a significant difference if we consider the range 21-33 and 33-45 y.o.
#
# - Both are **positive skewed histograms**, in fact, the mean is greater than the median. Most of the data is towards the left-hand side of the distribution, with a few large values to the right, in particular, the distirbution for women with no diabetes is more skewed than the one associated with women having diabetes, this can be seen also comparing the values for mean and median of the distirbutions.
# - Another difference between the two is the **magnitude of the bins**. The second histogram has higher frequencies than the first one, in particular for younger women, suggesting that the majority of young women in the sample do not have diabetes.

# %% [markdown]
# ## Q 19. What is Inter Quartile Range of all the variables? Why is it used? Which plot visualizes the same? (2 Marks)

# %%
Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                   5.0000
# Glucose                      41.2500
# BloodPressure                18.0000
# SkinThickness                32.0000
# Insulin                     127.2500
# BMI                           9.3000
# DiabetesPedigreeFunction      0.3825
# Age                          17.0000
# Outcome                       1.0000
# dtype: float64

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 19:
#
# IQR is the range computed on the middle 50% of the observations after removing the highest and lowest 25% in ascending ordered dataset. IQR is less affected by outliers than the range= Xmax-Xmin. The interquartile range tells us the spread of the middle half of the distribution. The plot used to visualize it is the boxplot. The IQR is useful to measure the variability of skewed distributions.
# For these distributions, the median is the best measure of central tendency because it’s the value exactly in the middle when all values are ordered from low to high. Along with the median, the IQR can give us an overview of where most of our values lie and how clustered they are. The IQR is also useful for datasets with outliers. Because it’s based on the middle half of the distribution, it’s less influenced by extreme values.
# <br> <br>
# In this case we can see that the highest variability is for the variable Insulin with IQR=127.25. Also glucose and and SkinThickness have moderate spread with respect to other variables in the dataset.

# %% [markdown]
# ## Q 20. Find and visualize the the correlation matrix. Write your observations from the plot. (3 Marks)

# %%
corr_matrix = pima.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)
# display the plot
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# Ans 20: From the heatplot we can see that there is no strong correlation between the variables, but however a certain level of correlation is still present among pairs of variables. <br> <br>
# A moderate positive correlation can be found between Age and Pregnancies, which is consistent with the reality considering also the range of values for the variable Age in our sample (with mean= 33.240885).
# Other correlations can be seen between:
# - **SkinThickness and Insulin 0.44**
# - **SkinThickness and BMI 0.39** meaning that higher skin thickness is present in those people having a higher BMI. Given that elevated BMIs are associated with a progressivly higher risk of complications from diabetes mellitus and also knowing that the skin of diabetic patients is thicker than the skin in healthy people, the result makes sense considering that in our dataset diabetic patients are present, thus, the result is consistent with the pathological condition.
# - **Gluose and Insulin 0.33** : there is a positive correlation, confirming the results also obtained from the scatterplot
# <br>
#
# Some of the variables have also negative correlation such as SkinThickness and Age, however the correlation is pretty low.
